# %% [markdown]
# # 37 · Group decoding summary, Nilearn distribution, and HTML report
# Subjects are the statistical units for the accuracy average. Nilearn is used only after functional electrode selection.

# %%
from pathlib import Path
import sys
ROOT=Path('/home/lirui/liulab_project/ieeg/Project_colorieeg_2026'); PIPE=ROOT/'color_cognition_pipeline'/'analyse_0720'; sys.path.insert(0,str(PIPE))
from utils.group_results import subject_accuracy_summary, plot_subject_accuracy_summary, nilearn_group_electrodes
from utils.report_html import generate
subject_accuracy_summary('union')
plot_subject_accuracy_summary('union')
nilearn_group_electrodes()
print(generate())
