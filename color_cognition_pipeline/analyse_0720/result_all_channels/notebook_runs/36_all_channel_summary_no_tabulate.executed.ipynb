# %% [markdown]
# # 36 · Whole-channel summary

# %%
from pathlib import Path
import sys,pandas as pd
ROOT=Path('/home/lirui/liulab_project/ieeg/Project_colorieeg_2026'); PIPE=ROOT/'color_cognition_pipeline'/'analyse_0720'; sys.path.insert(0,str(PIPE)); import config
tables=config.ALL_RESULT_ROOT/'group'/'tables'; screen=pd.read_csv(tables/'color_select_summary.csv'); prep=pd.read_csv(tables/'preprocessing_summary.csv'); excluded=pd.read_csv(tables/'excluded_subjects.csv'); display(screen); display(prep); display(excluded)
report=['# 全通道 color-select 分析报告','','- 不使用 fMRI 坐标或距离进行预筛选。','- Task1 仅作为功能 localizer；Task2/Task3 为独立验证。','- test004 因定位失败排除。','',screen.to_csv(index=False),'','虚拟被试结果表示跨被试电极汇集模式，不替代被试水平群体推断。']; (config.REPORT_ROOT/'all_channel_color_select_report.csv.md').write_text('\n'.join(report),encoding='utf-8')
# Out:
#    subject  n_color_select  erp_only  hg_only  intersection
# 0  test001               0         0        0             0
# 1  test002               0         0        0             0
# 2  test003               0         0        0             0
# 3  test005               0         0        0             0
# 4  test006               0         0        0             0
#     subject  task  epochs_before  epochs_rejected  epochs_kept  n_channels
# 0   test001     1            616               23          593          80
# 1   test001     2            792               44          748          80
# 2   test001     3            396               16          380          80
# 3   test002     1            616                2          614          54
# 4   test002     2            792                8          784          54
# 5   test002     3            396                0          396          54
# 6   test003     1            616               12          604         101
# 7   test003     2            792               21          771         101
# 8   test003     3            594               30          564         101
# 9   test005     1            615                3          612          78
# 10  test005     2            791                9          782          78
# 11  test005     3            396                0          396          78
# 12  test006     1            616               11          605          88
# 13  test006     2            792               18          774          88
# 14  test006     3            396                6          390          88
#    subject                         status
# 0  test004  excluded_localization_failure
# 276
