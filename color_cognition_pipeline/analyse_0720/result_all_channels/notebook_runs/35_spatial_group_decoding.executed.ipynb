# %% [markdown]
# # 35 · Atlas × hemisphere spatial groups
# Only localized, Task1-selected electrodes enter spatial grouping. Groups need ≥3 electrodes and ≥2 subjects.

# %%
from pathlib import Path
import sys
ROOT=Path('/home/lirui/liulab_project/ieeg/Project_colorieeg_2026'); PIPE=ROOT/'color_cognition_pipeline'/'analyse_0720'; sys.path.insert(0,str(PIPE)); import config
from utils.pseudopopulation import spatial_groups
summary=spatial_groups(); display(summary)
print('Eligible groups are defined for subsequent region-specific and cross-region decoding; decoding is skipped when no group meets both coverage criteria.')
# Out:
#                   spatial_group  n_electrodes  n_subjects  \
# 0             left | Fusiform L             1           1
# 1    left | Pars triangularis L             1           1
# 2        left | Supramarginal L             3           2
# 3                left | White L             4           2
# 4              right | Cuneus R             1           1
# 5         right | Hippocampus R             1           1
# 6   right | Inferior parietal R             2           2
# 7   right | Lateral occipital R             2           2
# 8   right | Rostral mid front R             1           1
# 9   right | Superior temporal R             1           1
# 10   right | WM-hypointensities             1           1
# 11              right | White R            14           3
#
#                    subjects  eligible
# 0                   test005     False
# 1                   test005     False
# 2           test005;test006      True
# 3           test005;test006      True
# ...
