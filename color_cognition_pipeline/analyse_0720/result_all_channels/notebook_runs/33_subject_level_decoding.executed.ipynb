# %% [markdown]
# # 33 · Subject-level decoding with Task1-selected electrodes

# %%
from pathlib import Path
import sys,pandas as pd
ROOT=Path('/home/lirui/liulab_project/ieeg/Project_colorieeg_2026'); PIPE=ROOT/'color_cognition_pipeline'/'analyse_0720'; sys.path.insert(0,str(PIPE)); import config
from utils.wholebrain import decode_subject
rows=[]
for subject in config.WHOLE_SUBJECTS: rows.extend(decode_subject(subject,('union','intersection')))
status=pd.DataFrame(rows); status.to_csv(config.ALL_RESULT_ROOT/'group'/'tables'/'subject_decoding_status.csv',index=False); display(status)
# Out:
#     subject modality electrode_set                     status
# 0   test001      erp         union  no_color_select_electrode
# 1   test001      erp  intersection  no_color_select_electrode
# 2   test001       hg         union  no_color_select_electrode
# 3   test001       hg  intersection  no_color_select_electrode
# 4   test002      erp         union  no_color_select_electrode
# 5   test002      erp  intersection  no_color_select_electrode
# 6   test002       hg         union  no_color_select_electrode
# 7   test002       hg  intersection  no_color_select_electrode
# 8   test003      erp         union  no_color_select_electrode
# 9   test003      erp  intersection  no_color_select_electrode
# 10  test003       hg         union  no_color_select_electrode
# 11  test003       hg  intersection  no_color_select_electrode
# 12  test005      erp         union  no_color_select_electrode
# 13  test005      erp  intersection  no_color_select_electrode
# 14  test005       hg         union  no_color_select_electrode
# 15  test005       hg  intersection  no_color_select_electrode
# 16  test006      erp         union  no_color_select_electrode
# 17  test006      erp  intersection  no_color_select_electrode
# 18  test006       hg         union  no_color_select_electrode
# 19  test006       hg  intersection  no_color_select_electrode
