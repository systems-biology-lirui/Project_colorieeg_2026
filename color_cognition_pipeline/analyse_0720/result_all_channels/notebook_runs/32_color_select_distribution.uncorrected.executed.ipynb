# %% [markdown]
# # 32 · Color-select electrode distribution
# Coordinates are used only after functional selection.

# %%
from pathlib import Path
import sys,pandas as pd,matplotlib.pyplot as plt
ROOT=Path('/home/lirui/liulab_project/ieeg/Project_colorieeg_2026'); PIPE=ROOT/'color_cognition_pipeline'/'analyse_0720'; sys.path.insert(0,str(PIPE)); import config
from utils.wholebrain import plot_distribution,location_table
from utils.plotting_science import set_science_style,save_figure,COLORS
for subject in config.WHOLE_SUBJECTS: plot_distribution(subject); plt.close('all')
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
rows=[]
for subject in config.WHOLE_SUBJECTS:
 sel=pd.read_csv(config.all_subject_dir(subject)/'color_select'/'color_select_electrodes.csv'); rows.append(sel)
all_sel=pd.concat(rows,ignore_index=True); all_sel.to_csv(config.ALL_RESULT_ROOT/'group'/'tables'/'color_select_all_subjects.csv',index=False)
set_science_style(); fig,axes=plt.subplots(1,2,figsize=(6.8,2.8),constrained_layout=True); colors={'ERP_only':COLORS['blue'],'HG_only':COLORS['orange'],'ERP_and_HG':COLORS['red']}
for ev,c in colors.items():
 d=all_sel[all_sel.color_select_evidence==ev]; axes[0].scatter(d.mni_x,d.mni_y,s=18,c=c,label=ev); axes[1].scatter(d.mni_y,d.mni_z,s=18,c=c,label=ev)
axes[0].set(xlabel='MNI X (mm)',ylabel='MNI Y (mm)'); axes[1].set(xlabel='MNI Y (mm)',ylabel='MNI Z (mm)'); axes[0].legend(); [ax.spines[['top','right']].set_visible(False) for ax in axes]; save_figure(fig,config.ALL_RESULT_ROOT/'group'/'figures'/'color_select_native_mni'); display(all_sel)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...
